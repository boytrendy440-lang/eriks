# %% [markdown]
# <a href="https://colab.research.google.com/github/boytrendy440-lang/eriks/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import skimage as sk
import matplotlib.pyplot as plt

from skimage import data
from skimage.filters import threshold_otsu

# Load image
img = data.coins()

# Compute Otsu threshold
T = threshold_otsu(img)

# Apply threshold
img_bin = img > T

# Display results
fig, ax = plt.subplots(1,2,figsize=(12,6))

ax[0].imshow(img,cmap=plt.cm.gray)
ax[0].set_title('Original Image')
ax[0].set_axis_off()

ax[1].imshow(img_bin,cmap=plt.cm.gray)
ax[1].set_title('Segmented Image')
ax[1].set_axis_off()

plt.show()

print('Otsu Threshold =',T)
# Out:
# Otsu Threshold = 107
